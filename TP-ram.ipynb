# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None
# %matplotlib inline

# %%
properati_2013_08 = pd.read_csv('Desktop/Datos/tp/properati-AR-2013-09-01-properties-sell.csv')
properati_2013_09 = pd.read_csv('Desktop/Datos/tp/properati-AR-2013-09-01-properties-sell.csv')
properati_2013_10 = pd.read_csv('Desktop/Datos/tp/properati-AR-2013-10-01-properties-sell.csv')
properati_2013_11 = pd.read_csv('Desktop/Datos/tp/properati-AR-2013-11-01-properties-sell.csv')
properati_2013_12 = pd.read_csv('Desktop/Datos/tp/properati-AR-2013-12-01-properties-sell.csv')

properati_2014_01 = pd.read_csv('Desktop/Datos/tp/properati-AR-2014-01-01-properties-sell.csv')
properati_2014_02 = pd.read_csv('Desktop/Datos/tp/properati-AR-2014-02-01-properties-sell.csv')
properati_2014_03 = pd.read_csv('Desktop/Datos/tp/properati-AR-2014-03-01-properties-sell.csv')
properati_2014_04 = pd.read_csv('Desktop/Datos/tp/properati-AR-2014-04-01-properties-sell.csv')
properati_2014_05 = pd.read_csv('Desktop/Datos/tp/properati-AR-2014-05-01-properties-sell.csv')
properati_2014_06 = pd.read_csv('Desktop/Datos/tp/properati-AR-2014-06-01-properties-sell.csv')
properati_2014_07 = pd.read_csv('Desktop/Datos/tp/properati-AR-2014-07-01-properties-sell.csv')
properati_2014_08 = pd.read_csv('Desktop/Datos/tp/properati-AR-2014-08-01-properties-sell.csv')
properati_2014_09 = pd.read_csv('Desktop/Datos/tp/properati-AR-2014-09-01-properties-sell.csv')
properati_2014_10 = pd.read_csv('Desktop/Datos/tp/properati-AR-2014-10-01-properties-sell.csv')
properati_2014_11 = pd.read_csv('Desktop/Datos/tp/properati-AR-2014-11-01-properties-sell.csv')
properati_2014_12 = pd.read_csv('Desktop/Datos/tp/properati-AR-2014-12-01-properties-sell.csv')

properati_2015_01 = pd.read_csv('Desktop/Datos/tp/properati-AR-2015-01-01-properties-sell.csv')
properati_2015_02 = pd.read_csv('Desktop/Datos/tp/properati-AR-2015-02-01-properties-sell.csv')
properati_2015_03 = pd.read_csv('Desktop/Datos/tp/properati-AR-2015-03-01-properties-sell.csv')
properati_2015_04 = pd.read_csv('Desktop/Datos/tp/properati-AR-2015-04-01-properties-sell.csv')
properati_2015_05 = pd.read_csv('Desktop/Datos/tp/properati-AR-2015-05-01-properties-sell.csv')
properati_2015_06 = pd.read_csv('Desktop/Datos/tp/properati-AR-2015-06-01-properties-sell.csv')
properati_2015_07 = pd.read_csv('Desktop/Datos/tp/properati-AR-2015-07-01-properties-sell.csv')
properati_2015_08 = pd.read_csv('Desktop/Datos/tp/properati-AR-2015-08-01-properties-sell.csv')
properati_2015_09 = pd.read_csv('Desktop/Datos/tp/properati-AR-2015-09-01-properties-sell.csv')
properati_2015_10 = pd.read_csv('Desktop/Datos/tp/properati-AR-2015-10-01-properties-sell.csv')
properati_2015_11 = pd.read_csv('Desktop/Datos/tp/properati-AR-2015-11-01-properties-sell.csv')
properati_2015_12 = pd.read_csv('Desktop/Datos/tp/properati-AR-2015-12-01-properties-sell.csv')

properati_2016_01 = pd.read_csv('Desktop/Datos/tp/properati-AR-2016-01-01-properties-sell.csv')
properati_2016_02 = pd.read_csv('Desktop/Datos/tp/properati-AR-2016-02-01-properties-sell.csv')
properati_2016_03 = pd.read_csv('Desktop/Datos/tp/properati-AR-2016-03-01-properties-sell.csv')
properati_2016_04 = pd.read_csv('Desktop/Datos/tp/properati-AR-2016-04-01-properties-sell.csv')
properati_2016_05 = pd.read_csv('Desktop/Datos/tp/properati-AR-2016-05-01-properties-sell.csv')
properati_2016_06 = pd.read_csv('Desktop/Datos/tp/properati-AR-2016-06-01-properties-sell.csv')
properati_2016_07 = pd.read_csv('Desktop/Datos/tp/properati-AR-2016-07-01-properties-sell.csv')
properati_2016_08 = pd.read_csv('Desktop/Datos/tp/properati-AR-2016-08-01-properties-sell.csv')
properati_2016_09 = pd.read_csv('Desktop/Datos/tp/properati-AR-2016-09-01-properties-sell.csv')
properati_2016_10 = pd.read_csv('Desktop/Datos/tp/properati-AR-2016-10-01-properties-sell.csv')
properati_2016_11 = pd.read_csv('Desktop/Datos/tp/properati-AR-2016-11-01-properties-sell.csv')
properati_2016_12 = pd.read_csv('Desktop/Datos/tp/properati-AR-2016-12-01-properties-sell.csv')

properati_2017_01 = pd.read_csv('Desktop/Datos/tp/properati-AR-2017-01-01-properties-sell.csv')
properati_2017_02 = pd.read_csv('Desktop/Datos/tp/properati-AR-2017-02-01-properties-sell.csv')
properati_2017_03 = pd.read_csv('Desktop/Datos/tp/properati-AR-2017-03-01-properties-sell.csv')
properati_2017_04 = pd.read_csv('Desktop/Datos/tp/properati-AR-2017-04-01-properties-sell.csv')
properati_2017_05 = pd.read_csv('Desktop/Datos/tp/properati-AR-2017-05-01-properties-sell.csv')
properati_2017_06 = pd.read_csv('Desktop/Datos/tp/properati-AR-2017-06-01-properties-sell.csv')
properati_2017_07 = pd.read_csv('Desktop/Datos/tp/properati-AR-2017-07-01-properties-sell.csv')
properati_2017_08 = pd.read_csv('Desktop/Datos/tp/properati-AR-2017-08-01-properties-sell.csv')
# Out:
# C:\Users\Ramiro\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\Ramiro\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
properati_2013_08.columns.values
# Out:
# array(['created_on', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'geonames_id', 'lat-lon', 'lat', 'lon',
#        'price', 'currency', 'price_aprox_local_currency',
#        'price_aprox_usd', 'surface_in_m2', 'price_usd_per_m2', 'floor',
#        'rooms', 'expenses', 'properati_url', 'image_thumbnail'], dtype=object)

# %%
len(properati_2013_08) -len(properati_2013_08.loc[properati_2013_08.created_on.str.contains("2013-08"),:])
# Out:
# 47301

# %%
properati_2013_08.loc[ properati_2013_08.created_on.str.contains("2013-08")== False,:].tail()
# Out:
#        created_on operation property_type             place_name  \
# 47296  2013-07-31      sell         house                Punilla
# 47297  2013-07-31      sell     apartment          Monte Hermoso
# 47298  2013-07-31      sell         house  San Salvador de Jujuy
# 47299  2013-07-31      sell     apartment                  Lanús
# 47300  2013-07-31      sell     apartment          Puerto Madero
#
#                                  place_with_parent_names  geonames_id  \
# 47296                        |Argentina|Córdoba|Punilla|    3839996.0
# 47297  |Argentina|Buenos Aires Costa Atlántica|Monte ...    3843843.0
# 47298            |Argentina|Jujuy|San Salvador de Jujuy|    3836564.0
# 47299           |Argentina|Bs.As. G.B.A. Zona Sur|Lanús|    3432134.0
# 47300          |Argentina|Capital Federal|Puerto Madero|    3429760.0
#
#                      lat-lon        lat        lon     price currency  \
# 47296  -30.993383,-64.476546 -30.993383 -64.476546       NaN      NaN
# ...

# %%
properati_2013_08 = properati_2013_08.loc[ properati_2013_08.created_on.str.contains("2013-08"),:]
properati_2013_09 = properati_2013_09.loc[ properati_2013_09.created_on.str.contains("2013-09"),:]
properati_2013_10 = properati_2013_10.loc[ properati_2013_10.created_on.str.contains("2013-10"),:]
properati_2013_11 = properati_2013_11.loc[ properati_2013_11.created_on.str.contains("2013-11"),:]
properati_2013_12 = properati_2013_12.loc[ properati_2013_12.created_on.str.contains("2013-12"),:]

properati_2014_01 = properati_2014_01.loc[ properati_2014_01.created_on.str.contains("2014-01"),:]
properati_2014_02 = properati_2014_02.loc[ properati_2014_02.created_on.str.contains("2014-02"),:]
properati_2014_03 = properati_2014_03.loc[ properati_2014_03.created_on.str.contains("2014-03"),:]
properati_2014_04 = properati_2014_04.loc[ properati_2014_04.created_on.str.contains("2014-04"),:]
properati_2014_05 = properati_2014_05.loc[ properati_2014_05.created_on.str.contains("2014-05"),:]
properati_2014_06 = properati_2014_06.loc[ properati_2014_06.created_on.str.contains("2014-06"),:]
properati_2014_07 = properati_2014_07.loc[ properati_2014_07.created_on.str.contains("2014-07"),:]
properati_2014_08 = properati_2014_08.loc[ properati_2014_08.created_on.str.contains("2014-08"),:]
properati_2014_09 = properati_2014_09.loc[ properati_2014_09.created_on.str.contains("2014-09"),:]
properati_2014_10 = properati_2014_10.loc[ properati_2014_10.created_on.str.contains("2014-10"),:]
properati_2014_11 = properati_2014_11.loc[ properati_2014_11.created_on.str.contains("2014-11"),:]
properati_2014_12 = properati_2014_12.loc[ properati_2014_12.created_on.str.contains("2014-12"),:]

properati_2015_01 = properati_2015_01.loc[ properati_2015_01.created_on.str.contains("2015-01"),:]
properati_2015_02 = properati_2015_02.loc[ properati_2015_02.created_on.str.contains("2015-02"),:]
properati_2015_03 = properati_2015_03.loc[ properati_2015_03.created_on.str.contains("2015-03"),:]
properati_2015_04 = properati_2015_04.loc[ properati_2015_04.created_on.str.contains("2015-04"),:]
properati_2015_05 = properati_2015_05.loc[ properati_2015_05.created_on.str.contains("2015-05"),:]
properati_2015_06 = properati_2015_06.loc[ properati_2015_06.created_on.str.contains("2015-06"),:]
properati_2015_07 = properati_2015_07.loc[ properati_2015_07.created_on.str.contains("2015-07"),:]
properati_2015_08 = properati_2015_08.loc[ properati_2015_08.created_on.str.contains("2015-08"),:]
properati_2015_09 = properati_2015_09.loc[ properati_2015_09.created_on.str.contains("2015-09"),:]
properati_2015_10 = properati_2015_10.loc[ properati_2015_10.created_on.str.contains("2015-10"),:]
properati_2015_11 = properati_2015_11.loc[ properati_2015_11.created_on.str.contains("2015-11"),:]
properati_2015_12 = properati_2015_12.loc[ properati_2015_12.created_on.str.contains("2015-12"),:]

properati_2016_01 = properati_2016_01.loc[ properati_2016_01.created_on.str.contains("2016-01"),:]
properati_2016_02 = properati_2016_02.loc[ properati_2016_02.created_on.str.contains("2016-02"),:]
properati_2016_03 = properati_2016_03.loc[ properati_2016_03.created_on.str.contains("2016-03"),:]
properati_2016_04 = properati_2016_04.loc[ properati_2016_04.created_on.str.contains("2016-04"),:]
properati_2016_05 = properati_2016_05.loc[ properati_2016_05.created_on.str.contains("2016-05"),:]
properati_2016_06 = properati_2016_06.loc[ properati_2016_06.created_on.str.contains("2016-06"),:]
properati_2016_07 = properati_2016_07.loc[ properati_2016_07.created_on.str.contains("2016-07"),:]
properati_2016_08 = properati_2016_08.loc[ properati_2016_08.created_on.str.contains("2016-08"),:]
properati_2016_09 = properati_2016_09.loc[ properati_2016_09.created_on.str.contains("2016-09"),:]
properati_2016_10 = properati_2016_10.loc[ properati_2016_10.created_on.str.contains("2016-10"),:]
properati_2016_11 = properati_2016_11.loc[ properati_2016_11.created_on.str.contains("2016-11"),:]
properati_2016_12 = properati_2016_12.loc[ properati_2016_12.created_on.str.contains("2016-12"),:]

properati_2017_01 = properati_2017_01.loc[ properati_2017_01.created_on.str.contains("2017-01"),:]
properati_2017_02 = properati_2017_02.loc[ properati_2017_02.created_on.str.contains("2017-02"),:]
properati_2017_03 = properati_2017_03.loc[ properati_2017_03.created_on.str.contains("2017-03"),:]
properati_2017_04 = properati_2017_04.loc[ properati_2017_04.created_on.str.contains("2017-04"),:]
properati_2017_05 = properati_2017_05.loc[ properati_2017_05.created_on.str.contains("2017-05"),:]
properati_2017_06 = properati_2017_06.loc[ properati_2017_06.created_on.str.contains("2017-06"),:]
properati_2017_07 = properati_2017_07.loc[ properati_2017_07.created_on.str.contains("2017-07"),:]
properati_2017_08 = properati_2017_08.loc[ properati_2017_08.created_on.str.contains("2017-08"),:]

# %%
interseccion = pd.merge(properati_2014_05,properati_2014_06, how='inner', on=['operation', 'property_type', 'place_name',
       'place_with_parent_names', 'geonames_id', 'lat-lon', 'lat', 'lon',
       'price', 'currency', 'price_aprox_local_currency',
       'price_aprox_usd', 'surface_in_m2', 'price_usd_per_m2', 'floor',
       'rooms', 'expenses', 'properati_url', 'image_thumbnail'])
len(interseccion) == 0
# Out:
# C:\Users\Ramiro\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1456: RuntimeWarning: divide by zero encountered in longlong_scalars
#   stride //= shape[i]
# True

# %%
properati = pd.concat([properati_2013_08,properati_2013_09,properati_2013_10,properati_2013_11,
                        properati_2013_12,properati_2014_01,properati_2014_02,properati_2014_03,
                        properati_2014_04,properati_2014_05,properati_2014_06,properati_2014_07,
                        properati_2014_08,properati_2014_09,properati_2014_10,properati_2014_11,
                        properati_2014_12,properati_2015_01,properati_2015_02,properati_2015_03,
                        properati_2015_04,properati_2015_05,properati_2015_06,properati_2015_07,
                        properati_2015_08,properati_2015_09,properati_2015_10,properati_2015_11,
                        properati_2015_12,properati_2016_01,properati_2016_02,properati_2016_03,
                        properati_2016_04,properati_2016_05,properati_2016_06,properati_2016_07,
                        properati_2016_08,properati_2016_09,properati_2016_10,properati_2016_11,
                        properati_2016_12,properati_2017_01,properati_2017_02,properati_2017_03,
                        properati_2017_04,properati_2017_05,properati_2017_06,properati_2017_07,
                        properati_2017_08])

# %%
properati.tail(3)
# Out:
#        country_name  created_on currency  \
# 187479    Argentina  2017-08-01      USD
# 187480    Argentina  2017-08-01      USD
# 187481    Argentina  2017-08-01      NaN
#
#                                               description expenses extra  \
# 187479  Excelente duplex 4 ambientes de 5m de frente x...      NaN   NaN
# 187480  Departameno 1º piso con balcon y terraza a est...      NaN   NaN
# 187481  Casa ubicada en una de las mejores zonas del B...      NaN   NaN
#
#         floor  geonames_id                                        id  \
# 187479    NaN    3430813.0  e935e6dca58a5b2fec2101f8c7ac1494722119a6
# 187480    NaN    3427407.0  d236e3424ac94ab9fcd5d2c22aed59eeed695adc
# 187481    NaN    3837856.0  9439664d30d10181efbae84ed01e6d991087deed
#
#                                           image_thumbnail  \
# 187479  https://thumbs4.properati.com/1/XKU2XF2BDkOtcg...
# 187480  https://thumbs4.properati.com/3/oj0WFPDQeGmrb0...
# ...

# %%
properati.dtypes
# Out:
# country_name                   object
# created_on                     object
# currency                       object
# description                    object
# expenses                       object
# extra                          object
# floor                         float64
# geonames_id                   float64
# id                             object
# image_thumbnail                object
# lat                           float64
# lat-lon                        object
# lon                           float64
# operation                      object
# place_name                     object
# place_with_parent_names        object
# price                         float64
# price_aprox_local_currency    float64
# price_aprox_usd               float64
# price_per_m2                  float64
# price_usd_per_m2              float64
# properati_url                  object
# property_type                  object
# rooms                         float64
# state_name                     object
# ...

# %%
#Filtro solo capital federal y gran buenos aires
properati.rename(columns={'created_on': 'FECHA'}, inplace=True)
capitalFederal = properati.loc[properati.state_name.str.contains("Capital Federal", na=False),:]
GBA =properati.loc[properati.state_name.str.contains("G.B.A", na=False),:]
properati_filter = pd.concat([capitalFederal,GBA])

# %%
#Filtro los que no tienen precio
properati_filter = properati_filter.loc[properati_filter.price.notnull(),:]

# %%
import calendar
properati_filter['FECHA'] = pd.to_datetime(properati_filter['FECHA'])
properati_filter.sample(10)
# Out:
#       country_name      FECHA currency  \
# 50427    Argentina 2017-03-15      USD
# 52712    Argentina 2017-01-26      USD
# 37595    Argentina 2016-06-02      USD
# 29244    Argentina 2016-11-10      USD
# 83264    Argentina 2017-06-13      ARS
# 30287    Argentina 2016-01-05      USD
# 52330    Argentina 2017-03-15      USD
# 20003    Argentina 2016-03-16      USD
# 41578    Argentina 2016-11-23      USD
# 13823    Argentina 2016-02-18      NaN
#
#                                              description expenses extra  \
# 50427  VENTA DEPARTAMENTO 4 AMBIENTES CABALLITOUnidad...      NaN   NaN
# 52712  En ALQUILER  y VENTA en VILLA URQUIZASIN EXPEN...      NaN   NaN
# 37595  Corredor Responsable: FLORENCIA BALAGUE - CMCP...      NaN   NaN
# 29244  EXCELENTE CASA!!!! Construida en 2 plantas. PB...      NaN   NaN
# 83264  CODIGO: 2704-321 - Curapaligue ubicado en: CUR...      NaN   NaN
# 30287  El emprendimiento de mayor envergadura de la Z...     9400   NaN
# ...

# %% [markdown]
# # ANÁLISIS

# %%
properati_gba =GBA.loc[:,['price_usd_per_m2','property_type','FECHA']]
properati_caba = capitalFederal.loc[:,['price_usd_per_m2','property_type','FECHA']]
properati_gba.dropna(inplace=True)
properati_caba.dropna(inplace=True)
properati_caba.count()
# Out:
# price_usd_per_m2    37931
# property_type       37931
# FECHA               37931
# dtype: int64

# %%
#Variación precio de distintas propiedades a lo largo de los años para el Gran Buenos Aires
# %matplotlib inline

fig = plt.figure(figsize=(10,4));

ax = fig.add_axes([0,0,1,1]);
properati_gba.loc[properati_gba['property_type'] == "house"].groupby('FECHA').mean().loc[:,'price_usd_per_m2'].plot.line(linewidth=2,figsize=(12,8), c='r', label="house");
properati_gba.loc[properati_gba['property_type'] == "apartment"].groupby('FECHA').mean().loc[:,'price_usd_per_m2'].plot.line(linewidth=2,figsize=(12,8), c='b', label="apartment");
properati_gba.loc[properati_gba['property_type'] == "PH"].groupby('FECHA').mean().loc[:,'price_usd_per_m2'].plot.line(linewidth=2,figsize=(12,8), c='g', label="PH");
properati_gba.loc[properati_gba['property_type'] == "store"].groupby('FECHA').mean().loc[:,'price_usd_per_m2'].plot.line(linewidth=2,figsize=(12,8), c='y', label="store");
plt.title('Precios de diferentes tipos de propiedades a lo largo del tiempo', fontsize=23);
plt.xlabel('Fecha', fontsize=16);
plt.ylabel('Precio por metro cuadrado en dólares', fontsize=16);
ax.legend(fontsize=13);

# %%
#Variación precio de distintas propiedades a lo largo de los años para Capital Federal
# %matplotlib inline

fig = plt.figure(figsize=(10,4));

ax = fig.add_axes([0,0,1,1]);
properati_caba.loc[properati_caba['property_type'] == "house"].groupby('FECHA').mean().loc[:,'price_usd_per_m2'].plot.line(linewidth=2,figsize=(12,8), c='r', label="house");
properati_caba.loc[properati_caba['property_type'] == "apartment"].groupby('FECHA').mean().loc[:,'price_usd_per_m2'].plot.line(linewidth=2,figsize=(12,8), c='b', label="apartment");
properati_caba.loc[properati_caba['property_type'] == "PH"].groupby('FECHA').mean().loc[:,'price_usd_per_m2'].plot.line(linewidth=2,figsize=(12,8), c='g', label="PH");
properati_caba.loc[properati_caba['property_type'] == "store"].groupby('FECHA').mean().loc[:,'price_usd_per_m2'].plot.line(linewidth=2,figsize=(12,8), c='y', label="store");
plt.title('Precios de diferentes tipos de propiedades a lo largo del tiempo', fontsize=23);
plt.xlabel('Fecha', fontsize=16);
plt.ylabel('Precio por metro cuadrado en dólares', fontsize=16);
ax.legend(fontsize=13);

# %% [markdown]
# Se puede notar con estos dos gráficos que en el Gran Buenos Aires son los almacenes los que maás han variado su precio en el último tiempo, seguidos por los departamentos, mientras que las casas y los PHs se han mantenido dentro de todo más constantes. Luego, en cuanto a la Capital Federal, a diferencia del Gran Buenos Aires lo que ha mostrado un gran golpe en cuanto al aumento de su precio son los PHs, en el mes de Mayo de 2016, seguido luego por los departamentos que también muestran un aumento notable en su precio en algunos meses, tanto en 2016 como 2017. Por otro lado las casas y los almacenes mantuvieron mejor su precio a lo largo de los años. Cabe destacar que tanto en Capital Federal como en el Gran Buenos Aires, los que siempre mantuvieron un precio no tan variable fueron las casas.

# %%
tipos_propiedades = GBA['property_type']
tipos_propiedades2 = capitalFederal['property_type']
tipos_propiedades.value_counts()
# Out:
# house        42868
# apartment    34130
# PH            5395
# store         1830
# Name: property_type, dtype: int64

# %%
tipos_propiedades2.value_counts()
# Out:
# apartment    45947
# house         4273
# PH            3921
# store         2282
# Name: property_type, dtype: int64

# %% [markdown]
# Al comprarar la cantidad de ventas de diferentes propiedades se puede ver claramente cuál es la Capital Federal y cual no. Como se observa, en la Capital hay una mayor compra de departamentos mientras que en el Gran Buenos Aires hay mayor compra de casas. Aunque podría ser que en ambas zonas haya una gran cantidad de casas, que haya más compra de departamentos en la Capital Federal que en el Gran Buenos Aires es un resultado bastante lógico.

# %% [markdown]
# A continuación se puede ver como claramente predomina la compra de departamentos en la ciudad:

# %%
from pandas import Series
capitalFederal_filtrada = capitalFederal.loc[:,['property_type','place_name']]
capitalFederal_filtrada.dropna(inplace=True)
capitalFederal_filtrada1 = capitalFederal_filtrada['property_type'].apply(lambda x: Series(x).value_counts()).sum()
capitalFederal_filtrada1.plot(kind='bar',figsize=(12,8));

# %%
properati_filter.sort_values('FECHA',ascending=False).tail(5)
# Out:
#       country_name      FECHA currency  \
# 14935    Argentina 2016-01-01      NaN
# 25746    Argentina 2016-01-01      USD
# 25744    Argentina 2016-01-01      USD
# 23653    Argentina 2016-01-01      USD
# 34420    Argentina 2016-01-01      USD
#
#                                              description expenses extra  \
# 14935  Corredor Responsable: Raul Hector Merlo - CUCI...      NaN   NaN
# 25746  Corredor Responsable: Jorge Di Pace - C.M.C.P....      NaN   NaN
# 25744  Corredor Responsable: Jorge Di Pace - C.M.C.P....      NaN   NaN
# 23653  Corredor Responsable: Carlos Belsito - C.M.C.P...      NaN   NaN
# 34420  Corredor Responsable: Jorge Salafia - CSI 5888...      NaN   NaN
#
#        floor  geonames_id                                        id  \
# 14935    5.0    3427366.0  33978e094f2cd32352b7b966d8895711e38eac5c
# 25746    NaN    3430544.0  c7b683081fd74493c1081ee589f86e9ecf375082
# 25744    2.0    3428983.0  132e5c8fba7bf1d5dc96f94c960ea9fbf7b781a8
# ...

# %%
properati_filter['FECHA'].hist(figsize=(16,8));
plt.xlabel('Fechas', fontsize=15);
plt.ylabel('Cantidad de Ventas', fontsize=20)
plt.title('Cantidad de ventas en relación con el tiempo', fontsize=20);

# %% [markdown]
# Se puede observar en este histograma como las ventas fueron aumentando casi de una manera constante, con pequeñas bajas, hasta Junio de este año, donde cayeron gravemente (a menos que haya una falta en el ingreso de datos por parte de la empresa).

# %%
properati_2016 = properati_filter.loc[properati_filter.FECHA.str.contains('2016'),:]
properati_2016.sort_values('FECHA',ascending=True).tail(5)
# Out:
#       country_name       FECHA currency  \
# 39713    Argentina  2016-12-31      USD
# 39714    Argentina  2016-12-31      USD
# 39715    Argentina  2016-12-31      USD
# 39705    Argentina  2016-12-31      USD
# 39654    Argentina  2016-12-31      USD
#
#                                              description expenses extra  \
# 39713  ***ALQUILADA HASTA JULIO 2017 | A LA LAGUNA | ...      NaN   NaN
# 39714  ESCRITURABLE / APTO CREDITO / Hermosa casa des...      NaN   NaN
# 39715  Escriturable, apto credito, lote interno Excel...      NaN   NaN
# 39705  ***A LA LAGUNA | PILETA | GARAGE CERRADO*** Ca...      NaN   NaN
# 39654  VENTA DE CASA EN UNA PLANTA AL FRENTE. 3 AMBIE...      NaN   NaN
#
#        floor  geonames_id                                        id  \
# 39713    NaN    3427753.0  8ca5fd796b4bc0ce45118fad4c1a7ffc38188d59
# 39714    NaN          NaN  94ed4135658507358162d24e7815edcece7d6688
# 39715    NaN          NaN  b78bd345abba7031cbdea4d24c70b218850ae774
# ...

# %% [markdown]
# Datos levantados de : http://www.datos.gob.ar/en/dataset/barrios-populares-argentina

# %%
#Cuento solo los que tienen su precio figurando en el dataset
total = properati_2016['price_usd_per_m2'].count()
print(total)
# Out:
# 46990

# %%
fechas_precios_2016 = properati_2016.loc[:,['FECHA','price_usd_per_m2']]
fechas_precios_2016.dropna(inplace=True)
fechas_precios_2016.count()
# Out:
# FECHA               46990
# price_usd_per_m2    46990
# dtype: int64

# %%
fechas_2016 = fechas_precios_2016[['FECHA']]
dias_no_enero2016 = fechas_2016[-(fechas_2016['FECHA'].str.startswith("2016-01"))]
dias_enero2016 = fechas_2016[(fechas_2016['FECHA'].str.startswith("2016-01"))]
sizes = [dias_no_enero2016.FECHA.count(), dias_enero2016.FECHA.count()]
nombres = ['              Resto del año', 'Enero']

plt.figure(figsize=(6, 6))
plt.title('Distribucion de ventas en el año 2016', fontsize=20)
plt.pie(sizes, labels=nombres, autopct='%1.1f%%', startangle=20, colors=['pink', 'grey'], explode=(0.1, 0))
plt.show()

# %%
properati_2017 = properati_filter.loc[properati_filter.FECHA.str.contains('2017'),:]
properati_2017.sort_values('FECHA',ascending=True).tail(5)
# Out:
#        country_name       FECHA currency  \
# 187205    Argentina  2017-08-01      USD
# 187202    Argentina  2017-08-01      USD
# 187201    Argentina  2017-08-01      USD
# 187253    Argentina  2017-08-01      USD
# 187479    Argentina  2017-08-01      USD
#
#                                               description expenses extra  \
# 187205  Departamento piso en Venta de 3 ambientes en P...      NaN   NaN
# 187202  Departamentos Semipisos en Venta de 3 ambiente...      NaN   NaN
# 187201  venta 4 ambientes c/dependencia y cochera en B...     5050   NaN
# 187253  VENTA PISO CON COCHERA EN PALERMOMuy buena ubi...     6246   NaN
# 187479  Excelente duplex 4 ambientes de 5m de frente x...      NaN   NaN
#
#         floor  geonames_id                                        id  \
# 187205    NaN    3433955.0  75969e8f6ed203bc265d9d5e45021f0af5a0b5b9
# 187202    NaN    3433955.0  e980d6eee46012a281f3f5cb07c698928898f63d
# ...

# %%
fechas_precios_2017 = properati_2017.loc[:,['FECHA','price_usd_per_m2']]
fechas_precios_2017.dropna(inplace=True)
fechas_2017 = fechas_precios_2017[['FECHA']]
dias_no_enero2017 = fechas_2017[-(fechas_2017['FECHA'].str.startswith("2017-01"))]
dias_enero2017 = fechas_2017[(fechas_2017['FECHA'].str.startswith("2017-01"))]
sizes = [dias_no_enero2017.FECHA.count(), dias_enero2017.FECHA.count()]
nombres = ['Resto del año hasta Agosto', 'Enero']

plt.figure(figsize=(6, 6))
plt.title('Distribucion de ventas en el año 2017', fontsize=20)
plt.pie(sizes, labels=nombres, autopct='%1.1f%%', startangle=20, colors=['red', 'yellow'], explode=(0.1, 0))
plt.show()

# %%
monto_acumulado2016 = fechas_precios_2016['price_usd_per_m2'].sum()
print(total)
# Out:
# 89473885.54289894

# %%
dias_enero2016 = fechas_precios_2016[(fechas_2016['FECHA'].str.startswith("2016-01"))]
precios_enero2016 = dias_enero2016[['price_usd_per_m2']]
monto_enero2016 = precios_enero2016['price_usd_per_m2'].sum()
print(monto_enero2016)
# Out:
# 3651585.4366986323

# %%
dias_no_enero2016 = fechas_precios_2016[-(fechas_2016['FECHA'].str.startswith("2016-01"))]
precios_no_enero2016 = dias_no_enero2016[['price_usd_per_m2']]
monto_no_enero2016 = precios_no_enero2016['price_usd_per_m2'].sum()
print(monto_no_enero2016)
# Out:
# 85822300.10619976

# %%
sizes = [monto_no_enero2016, monto_enero2016]
nombres = ['              Resto del año', 'Enero']

plt.figure(figsize=(6, 6))
plt.title('Distribucion precios de ventas en el año 2016', fontsize=20)
plt.pie(sizes, labels=nombres, autopct='%1.1f%%', startangle=20, colors=['pink', 'grey'], explode=(0.1, 0))
plt.show()

# %%
monto_acumulado2017 = fechas_precios_2017['price_usd_per_m2'].sum()
dias_enero2017 = fechas_precios_2017[(fechas_2017['FECHA'].str.startswith("2017-01"))]
precios_enero2017 = dias_enero2017[['price_usd_per_m2']]
monto_enero2017 = precios_enero2017['price_usd_per_m2'].sum()
dias_no_enero2017 = fechas_precios_2017[-(fechas_2017['FECHA'].str.startswith("2017-01"))]
precios_no_enero2017 = dias_no_enero2017[['price_usd_per_m2']]
monto_no_enero2017 = precios_no_enero2017['price_usd_per_m2'].sum()

sizes = [monto_no_enero2017, monto_enero2017]
nombres = ['Resto del año hasta Agosto', 'Enero']

plt.figure(figsize=(6, 6))
plt.title('Distribucion precios de ventas en el año 2017', fontsize=20)
plt.pie(sizes, labels=nombres, autopct='%1.1f%%', startangle=20, colors=['red', 'yellow'], explode=(0.1, 0))
plt.show()
